# %%
import pandas as pd

from itemloaders.processors import TakeFirst, MapCompose, Join, Compose

# %%
pd.read_csv('CrawlSpidercomparis/comparis/spiders/real-estate2.csv')
# Out:
#                              address  available_from  balcony  closest_shop  \
# 0                                NaN             NaN      NaN           NaN
# 1            8005 Zürich 8005 Zürich      À convenir      NaN           NaN
# 2     Turbinenstrasse 21 8005 Zürich      À convenir     True           NaN
# 3                        8005 Zürich      À convenir      NaN           100
# 4                        8005 Zürich      À convenir     True           100
# 5                        8005 Zürich      À convenir      NaN            50
# 6                            address  available_from  balcony  closest_shop
# 7                                NaN             NaN      NaN           NaN
# 8            8005 Zürich 8005 Zürich      À convenir      NaN           NaN
# 9     Turbinenstrasse 21 8005 Zürich      À convenir     True           NaN
# 10                       8005 Zürich      À convenir      NaN           100
# 11                       8005 Zürich      À convenir     True           100
# 12                       8005 Zürich      À convenir      NaN            50
# 13                           address  available_from  balcony  closest_shop
# 14                               NaN             NaN      NaN           NaN
# 15           8005 Zürich 8005 Zürich      À convenir      NaN           NaN
# 16    Turbinenstrasse 21 8005 Zürich      À convenir     True           NaN
# 17                       8005 Zürich      À convenir      NaN           100
# 18                       8005 Zürich      À convenir     True           100
# 19                       8005 Zürich      À convenir      NaN            50
# 20                           address  available_from  balcony  closest_shop
# 21                               NaN             NaN      NaN           NaN
# 22  Lindenbachstrasse 50 8006 Zürich      À convenir     True           NaN
# 23                       8006 Zürich      À convenir      NaN           NaN
# 24                       8006 Zürich      À convenir      NaN           NaN
# 25                       8005 Zürich      À convenir      NaN            50
# 26       Huttenstrasse 8 8006 Zürich      01.06.2022      NaN           206
#
#     contruction_year  dishwasher  dryer  elevator          floors  highway  \
# 0                NaN         NaN    NaN       NaN             NaN      NaN
# 1               2011         NaN    NaN      True       21. étage      NaN
# 2               2015         NaN    NaN      True        1. étage      NaN
# 3               2013         NaN    NaN      True       17. étage     3800
# 4               2004         NaN    NaN      True  Non disponible     1000
# 5               2005         NaN    NaN      True        4. étage     2000
# 6   contruction_year  dishwasher  dryer  elevator          floors  highway
# 7                NaN         NaN    NaN       NaN             NaN      NaN
# 8               2011         NaN    NaN      True       21. étage      NaN
# 9               2015         NaN    NaN      True        1. étage      NaN
# 10              2013         NaN    NaN      True       17. étage     3800
# 11              2004         NaN    NaN      True  Non disponible     1000
# 12              2005         NaN    NaN      True        4. étage     2000
# 13  contruction_year  dishwasher  dryer  elevator          floors  highway
# 14               NaN         NaN    NaN       NaN             NaN      NaN
# 15              2011         NaN    NaN      True       21. étage      NaN
# 16              2015         NaN    NaN      True        1. étage      NaN
# 17              2013         NaN    NaN      True       17. étage     3800
# 18              2004         NaN    NaN      True  Non disponible     1000
# 19              2005         NaN    NaN      True        4. étage     2000
# 20  contruction_year  dishwasher  dryer  elevator          floors  highway
# 21               NaN         NaN    NaN       NaN             NaN      NaN
# 22              1910         NaN    NaN      True        1. étage      NaN
# 23              1969         NaN    NaN       NaN  Non disponible      NaN
# 24    Non disponible         NaN    NaN       NaN  Non disponible      NaN
# 25              2005         NaN    NaN      True        4. étage     2000
# 26              1886         NaN    NaN       NaN        3. étage     6200
#
#     ...  parking_int        price  prim_school  public_transp           rooms  \
# 0   ...          NaN          NaN          NaN            NaN             NaN
# 1   ...         True  sur demande          NaN            NaN              11
# 2   ...         True    2'180'000          NaN            NaN             3.5
# 3   ...          NaN    2'590'000          630             50             3.5
# 4   ...         True    1'840'000          500            NaN             2.5
# 5   ...          NaN    2'050'000          600            300             2.5
# 6   ...  parking_int        price  prim_school  public_transp           rooms
# 7   ...          NaN          NaN          NaN            NaN             NaN
# 8   ...         True  sur demande          NaN            NaN              11
# 9   ...         True    2'180'000          NaN            NaN             3.5
# 10  ...          NaN    2'590'000          630             50             3.5
# 11  ...         True    1'840'000          500            NaN             2.5
# 12  ...          NaN    2'050'000          600            300             2.5
# 13  ...  parking_int        price  prim_school  public_transp           rooms
# 14  ...          NaN          NaN          NaN            NaN             NaN
# 15  ...         True  sur demande          NaN            NaN              11
# 16  ...         True    2'180'000          NaN            NaN             3.5
# 17  ...          NaN    2'590'000          630             50             3.5
# 18  ...         True    1'840'000          500            NaN             2.5
# 19  ...          NaN    2'050'000          600            300             2.5
# 20  ...  parking_int        price  prim_school  public_transp           rooms
# 21  ...          NaN          NaN          NaN            NaN             NaN
# 22  ...          NaN    1'350'000          NaN            NaN             3.5
# 23  ...          NaN  sur demande          NaN            NaN  Non disponible
# 24  ...          NaN  sur demande          NaN            NaN  Non disponible
# 25  ...          NaN    2'050'000          600            300             2.5
# 26  ...          NaN    1'250'000          267            978             3.5
#
#     secon_school       sq_meters    tv         type  wash_m
# 0            NaN             NaN   NaN          NaN     NaN
# 1            NaN             603   NaN  Appartement     NaN
# 2            NaN             108  True  Appartement     NaN
# 3           1500             120   NaN  Appartement     NaN
# 4            500              84  True  Appartement     NaN
# 5            600             105   NaN         Loft     NaN
# 6   secon_school       sq_meters    tv         type  wash_m
# 7            NaN             NaN   NaN          NaN     NaN
# 8            NaN             603   NaN  Appartement     NaN
# 9            NaN             108  True  Appartement     NaN
# 10          1500             120   NaN  Appartement     NaN
# 11           500              84  True  Appartement     NaN
# 12           600             105   NaN         Loft     NaN
# 13  secon_school       sq_meters    tv         type  wash_m
# 14           NaN             NaN   NaN          NaN     NaN
# 15           NaN             603   NaN  Appartement     NaN
# 16           NaN             108  True  Appartement     NaN
# 17          1500             120   NaN  Appartement     NaN
# 18           500              84  True  Appartement     NaN
# 19           600             105   NaN         Loft     NaN
# 20  secon_school       sq_meters    tv         type  wash_m
# 21           NaN             NaN   NaN          NaN     NaN
# 22           NaN              66  True  Appartement     NaN
# 23           NaN  Non disponible   NaN     Immeuble     NaN
# 24           NaN  Non disponible   NaN        Autre     NaN
# 25           600             105   NaN         Loft     NaN
# 26           935              69   NaN      Attique     NaN
#
# [27 rows x 22 columns]

# %%
proc = Compose(lambda v: v[0], str.upper)

# %%
proc(['hello','world'])
# Out:
# 'HELLO'
