# %%
import pandas as pd

# %%
pd.read_csv('CrawlSpidercomparis/comparis/spiders/real-estate.csv')
# Out:
#                                                address  \
# 0                                                  NaN
# 1    <h5 class="css-15z12tn ehesakb2"><style data-e...
# 2    <h5 class="css-15z12tn ehesakb2"><style data-e...
# 3    <h5 class="css-15z12tn ehesakb2"><style data-e...
# 4    <h5 class="css-15z12tn ehesakb2"><style data-e...
# ..                                                 ...
# 115                            8005 Zürich 8005 Zürich
# 116                     Turbinenstrasse 21 8005 Zürich
# 117                                        8005 Zürich
# 118                                        8005 Zürich
# 119                                        8005 Zürich
#
#                                                  price  \
# 0                                                  NaN
# 1    <h3 class="css-eujsoq ehesakb2">CHF 1'450'000<...
# 2    <h3 class="css-eujsoq ehesakb2">auf Anfrage<st...
# 3    <h3 class="css-eujsoq ehesakb2">CHF 495'000<st...
# ...
