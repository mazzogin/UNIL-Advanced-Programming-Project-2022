# %%
import pandas as pd

from itemloaders.processors import TakeFirst, MapCompose, Join, Compose

# %%
pd.read_csv('CrawlSpidercomparis/comparis/spiders/real-estate4.csv')
# Out:
#                              address  available_from balcony  closest_shop  \
# 0                        8005 Zürich  By arrangement     NaN           NaN
# 1                        8005 Zürich  By arrangement     NaN           NaN
# 2   Technoparkstrasse 10 8005 Zürich  By arrangement    True           NaN
# 3                        8005 Zürich  By arrangement     NaN           NaN
# 4  Förrlibuckstrasse 185 8005 Zürich     Immediately     NaN           NaN
# 5            8005 Zürich 8005 Zürich  By arrangement     NaN           NaN
# 6     Turbinenstrasse 21 8005 Zürich  By arrangement    True           NaN
# 7                        8005 Zürich  By arrangement     NaN           NaN
# 8                        8005 Zürich  By arrangement    True           NaN
#
#   contruction_year  dishwasher  dryer  elevator         floors  highway  ...  \
# 0             2005         NaN    NaN       NaN       4. floor      NaN  ...
# ...

# %%
proc = Compose(lambda v: v[0], str.upper)

# %%
proc(['hello','world'])
# Out:
# 'HELLO'

# %%
import pandas as pd
pd.read_csv('/Users/gino/University-and-Education/UNIL/Advanced-Programming/Comparis_Webscraper/Comparis_Webscraper/spiders/test2.csv')
# Out:
#                              address available_from balcony  closest_shop  \
# 0                        8005 Zürich     À convenir     NaN          50.0
# 1                        8005 Zürich     À convenir    True         100.0
# 2                        8005 Zürich     À convenir     NaN         100.0
# 3     Turbinenstrasse 21 8005 Zürich     À convenir    True           NaN
# 4            8005 Zürich 8005 Zürich     À convenir     NaN           NaN
# 5  Förrlibuckstrasse 185 8005 Zürich      Immédiate     NaN           NaN
# 6                        8005 Zürich     À convenir     NaN           NaN
# 7   Technoparkstrasse 10 8005 Zürich     À convenir    True           NaN
# 8                        8005 Zürich     À convenir     NaN           NaN
#
#   contruction_year  dishwasher  dryer elevator          floors  highway  ...  \
# 0             2005         NaN    NaN     True        4. étage   2000.0  ...
# ...

# %%
import pandas as pd
properties_lausanne = pd.read_csv('/Users/gino/University-and-Education/UNIL/Advanced-Programming/data/property_details.csv')

# %%
print(properties_lausanne)
# Out:
#                               address available_from balcony  closest_shop  \
# 0                       1012 Lausanne     À convenir     NaN           NaN
# 1                       1004 Lausanne      Immédiate     NaN           NaN
# 2    La Conversion 1093 La Conversion     01.07.2022     NaN         403.0
# 3                      1026 Echandens     À convenir     NaN           NaN
# 4                      1066 Epalinges     À convenir     NaN           NaN
# ..                                ...            ...     ...           ...
# 870                      1053 Cugy VD     À convenir     NaN           NaN
# 871    Av de la gare 20 1003 Lausanne      Immédiate     NaN           NaN
# 872         1092 Belmont-sur-Lausanne     À convenir    True           NaN
# 873                    1066 Epalinges      Immédiate     NaN           NaN
# 874                  1024 Ecublens VD     À convenir    True         300.0
#
# ...
